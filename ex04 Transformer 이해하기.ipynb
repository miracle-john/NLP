# %% [markdown]
# ### RNN 활용 케이스
# - Keras 순환신경망 레이어는 기본적으로 many to one 구조
# - 순환신경망을 다층으로 쌓고 싶을 때는 이전 레이어를 many to many로 변경 -> return_sequences=True 속성 활용

# %% [markdown]
# ![image 11.png](data:image/png;base64,...)
